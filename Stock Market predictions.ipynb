# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.52-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: html5lib>=1.1 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.1)
# Collecting pytz>=2022.5
#   Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#      |████████████████████████████████| 507 kB 22.6 MB/s eta 0:00:01
# Collecting peewee>=3.16.2
#   Downloading peewee-3.17.9.tar.gz (3.0 MB)
#      |████████████████████████████████| 3.0 MB 133.9 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.6.2)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.6-cp38-cp38-macosx_10_9_x86_64.whl (37 kB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting lxml>=4.9.1
#   Downloading lxml-5.3.0-cp38-cp38-macosx_10_9_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 116.1 MB/s eta 0:00:01
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#      |████████████████████████████████| 186 kB 66.8 MB/s eta 0:00:01
# Collecting requests>=2.31
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting pandas>=1.3.0
#   Downloading pandas-2.0.3-cp38-cp38-macosx_10_9_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 49.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.5 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: six>=1.9 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.0.1)
# Collecting typing-extensions>=4.0.0
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.31->yfinance) (1.25.11)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-py3-none-any.whl (49 kB)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 152.2 MB/s eta 0:00:01
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (PEP 517) ... done
#   Created wheel for peewee: filename=peewee-3.17.9-cp38-cp38-macosx_10_9_x86_64.whl size=282281 sha256=a52470958c7e6aa017ef437cb6463edec6e5ac71ad63ccc27b7a387dad7cda98
#   Stored in directory: /Users/ali/Library/Caches/pip/wheels/5f/5b/2b/f993083c828c66707ef9e516072f4b3b41d6c68cf00ab57e77
# Successfully built peewee
# Installing collected packages: pytz, peewee, frozendict, multitasking, lxml, typing-extensions, beautifulsoup4, charset-normalizer, requests, tzdata, python-dateutil, pandas, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2020.1
#     Uninstalling pytz-2020.1:
#       Successfully uninstalled pytz-2020.1
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.6.1
#     Uninstalling lxml-4.6.1:
#       Successfully uninstalled lxml-4.6.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.9.3
#     Uninstalling beautifulsoup4-4.9.3:
#       Successfully uninstalled beautifulsoup4-4.9.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.3
#     Uninstalling pandas-1.1.3:
#       Successfully uninstalled pandas-1.1.3
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# pandas 2.0.3 requires numpy>=1.20.3; python_version < "3.10", but you'll have numpy 1.19.2 which is incompatible.
# Successfully installed beautifulsoup4-4.13.3 charset-normalizer-3.4.1 frozendict-2.4.6 lxml-5.3.0 multitasking-0.0.11 pandas-2.0.3 peewee-3.17.9 python-dateutil-2.9.0.post0 pytz-2025.1 requests-2.32.3 typing-extensions-4.12.2 tzdata-2025.1 yfinance-0.2.52
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade numpy
# Out:
# Collecting numpy
#   Using cached numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2
# Successfully installed numpy-1.24.4

# %%
import yfinance as yf

# %%
# !pip install --upgrade numexpr
# Out:
# Collecting numexpr
#   Downloading numexpr-2.8.6-cp38-cp38-macosx_10_9_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 4.3 MB/s ta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from numexpr) (1.24.4)
# Installing collected packages: numexpr
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.7.1
#     Uninstalling numexpr-2.7.1:
#       Successfully uninstalled numexpr-2.7.1
# Successfully installed numexpr-2.8.6

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(
astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-02-03 00:00:00-05:00  5969.649902  6022.129883  5923.930176  5994.569824
# 2025-02-04 00:00:00-05:00  5998.140137  6042.479980  5990.870117  6037.879883
# 2025-02-05 00:00:00-05:00  6020.450195  6062.859863  6007.060059  6061.479980
# 2025-02-06 00:00:00-05:00  6072.220215  6084.029785  6046.830078  6083.569824
# 2025-02-07 00:00:00-05:00  6083.129883  6101.279785  6019.959961  6025.990234
#
#                                Volume     Tomorrow  Target
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000       1
# 1928-01-03 00:00:00-05:00           0    17.719999       0
# 1928-01-04 00:00:00-05:00           0    17.549999       0
# 1928-01-05 00:00:00-05:00           0    17.660000       1
# 1928-01-06 00:00:00-05:00           0    17.500000       0
# ...                               ...          ...     ...
# 2025-02-03 00:00:00-05:00  4797210000  6037.879883       1
# 2025-02-04 00:00:00-05:00  4410160000  6061.479980       1
# 2025-02-05 00:00:00-05:00  4756250000  6083.569824       1
# 2025-02-06 00:00:00-05:00  4847120000  6025.990234       0
# 2025-02-07 00:00:00-05:00  4766900000          NaN       0
#
# [24392 rows x 7 columns]

# %%
sp500 = sp500.loc['1990-01-01':].copy()

# %%
import numpy as np
np.float = float  # Temporary workaround (not recommended long-term)

# %%
print(sklearn.__version__)
# Out:
# 1.3.2

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.5.0 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=1.1.1 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.17.3 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn) (1.24.4)

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

# %%
train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ['Close', 'Volume', 'Open', 'High', 'Low']

model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

# %%
preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
precision_score(test['Target'], preds)
# Out:
# 1.0

# %%
combined = pd.concat([test['Target'], preds], axis=1)

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train['Target'])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name='Predictions')
    combined = pd.concat([test['Target'], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i: (i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0    3707
# 1    2635
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5286527514231499

# %%
predictions['Target'].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.536108
# 0    0.463892
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]  #2 days, 5 days, 3 months, last year, last 5 years
new_predictors =[]

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f'Close_Ratio_{horizon}'
    sp500[ratio_column] = sp500['Close'] / rolling_averages['Close']
    
    trend_column = f'Trend_{horizon}'
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()['Target']
    
    new_predictors += [ratio_column, trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-02-03 00:00:00-05:00  5969.649902  6022.129883  5923.930176  5994.569824
# 2025-02-04 00:00:00-05:00  5998.140137  6042.479980  5990.870117  6037.879883
# 2025-02-05 00:00:00-05:00  6020.450195  6062.859863  6007.060059  6061.479980
# 2025-02-06 00:00:00-05:00  6072.220215  6084.029785  6046.830078  6083.569824
# 2025-02-07 00:00:00-05:00  6083.129883  6101.279785  6019.959961  6025.990234
#
#                                Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0            NaN
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0       0.998706
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0       0.995675
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1       0.995098
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0       1.002252
# ...                               ...          ...     ...            ...
# 2025-02-03 00:00:00-05:00  4797210000  6037.879883       1       0.996181
# 2025-02-04 00:00:00-05:00  4410160000  6061.479980       1       1.003599
# 2025-02-05 00:00:00-05:00  4756250000  6083.569824       1       1.001951
# 2025-02-06 00:00:00-05:00  4847120000  6025.990234       0       1.001819
# 2025-02-07 00:00:00-05:00  4766900000          NaN       0       0.995245
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 1990-01-02 00:00:00-05:00      NaN            NaN      NaN             NaN
# 1990-01-03 00:00:00-05:00      NaN            NaN      NaN             NaN
# 1990-01-04 00:00:00-05:00      0.0            NaN      NaN             NaN
# 1990-01-05 00:00:00-05:00      0.0            NaN      NaN             NaN
# 1990-01-08 00:00:00-05:00      1.0       0.993731      NaN             NaN
# ...                            ...            ...      ...             ...
# 2025-02-03 00:00:00-05:00      0.0       0.992042      2.0        1.001959
# 2025-02-04 00:00:00-05:00      1.0       1.000197      2.0        1.008482
# 2025-02-05 00:00:00-05:00      2.0       1.003369      3.0        1.012051
# 2025-02-06 00:00:00-05:00      2.0       1.006613      3.0        1.015427
# 2025-02-07 00:00:00-05:00      1.0       0.997565      3.0        1.005731
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1990-01-02 00:00:00-05:00       NaN              NaN        NaN
# 1990-01-03 00:00:00-05:00       NaN              NaN        NaN
# 1990-01-04 00:00:00-05:00       NaN              NaN        NaN
# 1990-01-05 00:00:00-05:00       NaN              NaN        NaN
# 1990-01-08 00:00:00-05:00       NaN              NaN        NaN
# ...                             ...              ...        ...
# 2025-02-03 00:00:00-05:00      35.0         1.083820      142.0
# 2025-02-04 00:00:00-05:00      35.0         1.090787      143.0
# 2025-02-05 00:00:00-05:00      35.0         1.094175      143.0
# 2025-02-06 00:00:00-05:00      35.0         1.097300      143.0
# 2025-02-07 00:00:00-05:00      34.0         1.086108      142.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 1990-01-02 00:00:00-05:00               NaN         NaN
# 1990-01-03 00:00:00-05:00               NaN         NaN
# 1990-01-04 00:00:00-05:00               NaN         NaN
# 1990-01-05 00:00:00-05:00               NaN         NaN
# 1990-01-08 00:00:00-05:00               NaN         NaN
# ...                                     ...         ...
# 2025-02-03 00:00:00-05:00          1.311448       526.0
# 2025-02-04 00:00:00-05:00          1.320308       527.0
# 2025-02-05 00:00:00-05:00          1.324847       527.0
# 2025-02-06 00:00:00-05:00          1.329051       527.0
# 2025-02-07 00:00:00-05:00          1.315870       527.0
#
# [8842 rows x 17 columns]

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2025-01-31 00:00:00-05:00  6096.790039  6120.910156  6030.930176  6040.529785
# 2025-02-03 00:00:00-05:00  5969.649902  6022.129883  5923.930176  5994.569824
# 2025-02-04 00:00:00-05:00  5998.140137  6042.479980  5990.870117  6037.879883
# 2025-02-05 00:00:00-05:00  6020.450195  6062.859863  6007.060059  6061.479980
# 2025-02-06 00:00:00-05:00  6072.220215  6084.029785  6046.830078  6083.569824
#
#                                Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 1993-12-14 00:00:00-05:00   275050000   461.839996       0       0.997157
# 1993-12-15 00:00:00-05:00   331770000   463.339996       1       0.998681
# 1993-12-16 00:00:00-05:00   284620000   466.380005       1       1.001621
# 1993-12-17 00:00:00-05:00   363750000   465.850006       0       1.003270
# 1993-12-20 00:00:00-05:00   255900000   465.299988       0       0.999431
# ...                               ...          ...     ...            ...
# 2025-01-31 00:00:00-05:00  4843770000  5994.569824       0       0.997470
# 2025-02-03 00:00:00-05:00  4797210000  6037.879883       1       0.996181
# 2025-02-04 00:00:00-05:00  4410160000  6061.479980       1       1.003599
# 2025-02-05 00:00:00-05:00  4756250000  6083.569824       1       1.001951
# 2025-02-06 00:00:00-05:00  4847120000  6025.990234       0       1.001819
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 1993-12-14 00:00:00-05:00      1.0       0.996617      1.0        1.000283
# 1993-12-15 00:00:00-05:00      0.0       0.995899      1.0        0.997329
# 1993-12-16 00:00:00-05:00      1.0       0.999495      2.0        1.000311
# 1993-12-17 00:00:00-05:00      2.0       1.004991      3.0        1.006561
# 1993-12-20 00:00:00-05:00      1.0       1.003784      2.0        1.005120
# ...                            ...            ...      ...             ...
# 2025-01-31 00:00:00-05:00      1.0       0.999063      2.0        1.010435
# 2025-02-03 00:00:00-05:00      0.0       0.992042      2.0        1.001959
# 2025-02-04 00:00:00-05:00      1.0       1.000197      2.0        1.008482
# 2025-02-05 00:00:00-05:00      2.0       1.003369      3.0        1.012051
# 2025-02-06 00:00:00-05:00      2.0       1.006613      3.0        1.015427
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1993-12-14 00:00:00-05:00      32.0         1.028047      127.0
# 1993-12-15 00:00:00-05:00      32.0         1.025151      126.0
# 1993-12-16 00:00:00-05:00      32.0         1.028274      127.0
# 1993-12-17 00:00:00-05:00      32.0         1.034781      128.0
# 1993-12-20 00:00:00-05:00      32.0         1.033359      128.0
# ...                             ...              ...        ...
# 2025-01-31 00:00:00-05:00      35.0         1.092948      143.0
# 2025-02-03 00:00:00-05:00      35.0         1.083820      142.0
# 2025-02-04 00:00:00-05:00      35.0         1.090787      143.0
# 2025-02-05 00:00:00-05:00      35.0         1.094175      143.0
# 2025-02-06 00:00:00-05:00      35.0         1.097300      143.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 1993-12-14 00:00:00-05:00          1.176082       512.0
# 1993-12-15 00:00:00-05:00          1.172676       512.0
# 1993-12-16 00:00:00-05:00          1.176163       513.0
# 1993-12-17 00:00:00-05:00          1.183537       514.0
# 1993-12-20 00:00:00-05:00          1.181856       513.0
# ...                                     ...         ...
# 2025-01-31 00:00:00-05:00          1.322105       526.0
# 2025-02-03 00:00:00-05:00          1.311448       526.0
# 2025-02-04 00:00:00-05:00          1.320308       527.0
# 2025-02-05 00:00:00-05:00          1.324847       527.0
# 2025-02-06 00:00:00-05:00          1.329051       527.0
#
# [7841 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train['Target'])
    preds = model.predict_proba(test[predictors]) [:,1] #returns a probability if row will be 0 or 1
    preds[preds >= .6] = 1
    preds[preds < .6] =0
    preds = pd.Series(preds, index=test.index, name='Predictions')
    combined = pd.concat([test['Target'], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0.0    4478
# 1.0     863
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5758980301274623
